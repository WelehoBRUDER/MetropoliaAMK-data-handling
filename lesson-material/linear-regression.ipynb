# %%
import pandas as pd

df = pd.read_csv('../datasets/tvmarketing.csv')
df.head()
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9

# %%
import matplotlib.pyplot as plt

X = df.drop(columns='Sales') # inputs
y = df['Sales'] # targets
plt.scatter(X, y)
plt.xlabel('TV Advertising (1000$)')
plt.ylabel('Sales revenue (M$)')
plt.show()

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
b0 = model.intercept_
b1 = model.coef_[0]
print(f'Intercept: {b0:.2f}, Coefficient: {b1:.4f}')
# Out:
# Intercept: 7.03, Coefficient: 0.0475

# %%
import numpy as np

xs = np.linspace(X.min(), X.max())
ys = b0 + b1 * xs
plt.plot(xs, ys)
plt.scatter(X, y)
plt.xlabel('TV Advertising (1000$)')
plt.ylabel('Sales revenue (M$)')
plt.show()

# %%
from sklearn.metrics import mean_absolute_error

preds = model.predict(X)

print(f'Mean absolute error: {mean_absolute_error(y, preds):.2f}')
# Out:
# Mean absolute error: 2.55

# %%
plt.scatter(X, preds - y)
plt.xlabel('TV Advertising (1000$)')
plt.ylabel('Sales revenue (M$)')
plt.show()
