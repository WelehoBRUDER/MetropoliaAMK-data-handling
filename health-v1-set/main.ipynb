# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('health_v1.csv', sep=';', na_values='NaN')
df.head()
df.dtypes
# Out:
# ID               int64
# Weight         float64
# Smoking        float64
# Exercise        object
# Cholesterol     object
# Income          object
# Happiness      float64
# BirthYear       object
# Sex             object
# dtype: object

# %% [markdown]
# ## Find uniques

# %%
df.Sex.unique()
# Out:
# array(['1', '2', 'Male', 'Female'], dtype=object)

# %%
df['Sex'] = df['Sex'].astype('str')
df['Sex'] = df['Sex'].replace({'Male': '1', 'Female': '2'})
df['Sex'] = df['Sex'].astype('category')

df.dtypes

df.Sex.unique()
# Out:
# ['1', '2']
# Categories (2, object): ['1', '2']

# %%
df.describe(include='all')
# Out:
#                  ID      Weight     Smoking Exercise Cholesterol Income  \
# count   1000.000000  999.000000  999.000000     1000        1000    999
# unique          NaN         NaN         NaN       12          72    425
# top             NaN         NaN         NaN        5         5,8      0
# freq            NaN         NaN         NaN      199          41      9
# mean     500.500000   79.717718    0.232232      NaN         NaN    NaN
# std      288.819436   25.252719    0.422468      NaN         NaN    NaN
# min        1.000000    8.000000    0.000000      NaN         NaN    NaN
# 25%      250.750000   70.000000    0.000000      NaN         NaN    NaN
# 50%      500.500000   80.000000    0.000000      NaN         NaN    NaN
# 75%      750.250000   88.000000    0.000000      NaN         NaN    NaN
# max     1000.000000  740.000000    1.000000      NaN         NaN    NaN
#
#          Happiness BirthYear   Sex
# count   999.000000      1000  1000
# unique         NaN       117     2
# top            NaN      1942     1
# freq           NaN        24   523
# mean     51.171171       NaN   NaN
# std      17.511569       NaN   NaN
# min       0.000000       NaN   NaN
# 25%      39.000000       NaN   NaN
# 50%      50.000000       NaN   NaN
# 75%      63.000000       NaN   NaN
# max     100.000000       NaN   NaN

# %%
def plot_data(df):
    plt.figure(figsize=(20, 10))
    for i, col in enumerate(df.select_dtypes(include=['int', 'float'])):
        plt.subplot(3, 3, i+1)
        df[col].plot(kind='hist', title=col)
        plt.xlabel(col)
        
plot_data(df)
